# %% [markdown]
# <a href="https://colab.research.google.com/github/Biacrispim/Formulario/blob/main/atividade01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("olá terraqueos!!!")
# Out:
# olá terraqueos!!!

# %%
numero=input("digite um numero:")
print("o numero informado foi:" , numero)
# Out:
# digite um numero:10
# o numero informado foi: 10

# %%
numero1 = float(input("Digite o primeiro número: "))
numero2 = float(input("Digite o segundo número: "))

soma = numero1 + numero2

print("A soma dos números é:", soma)
# Out:
# Digite o primeiro número: 2
# Digite o segundo número: 5
# A soma dos números é: 7.0

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
nota4 = float(input("Digite a quarta nota: "))

media = (nota1 + nota2 + nota3 + nota4) / 4

print("A média das notas é:", media)
# Out:
# Digite a primeira nota: 10
# Digite a segunda nota: 5
# Digite a terceira nota: 10
# Digite a quarta nota: 10
# A média das notas é: 8.75

# %%
metros = float(input("Digite o valor em metros: "))

centimetros = metros * 100

print("O valor em centímetros é:", centimetros)
# Out:
# Digite o valor em metros: 30
# O valor em centímetros é: 3000.0

# %%
import math

raio = float(input("Digite o raio do círculo: "))

area = math.pi * (raio * 2)

print("A área do círculo é:", area)
# Out:
# Digite o raio do círculo: 10
# A área do círculo é: 62.83185307179586

# %%
lado = float(input("Digite o lado do quadrado: "))

area = lado * lado
dobro_area = area * 2

print("A área do quadrado é:", area)
print("O dobro da área é:", dobro_area)
# Out:
# Digite o lado do quadrado: 40
# A área do quadrado é: 1600.0
# O dobro da área é: 3200.0

# %%
valor_hora = float(input("Quanto você ganha por hora? "))
horas_trabalhadas = float(input("Quantas horas você trabalhou no mês? "))

salario = valor_hora * horas_trabalhadas

print("Seu salário neste mês foi de R$", salario)

# %%
fahrenheit = float(input("Digite a temperatura em Fahrenheit: "))

celsius = 5 * ((fahrenheit - 32) / 9)

print("A temperatura em Celsius é:", celsius)

# %%
celsius = float(input("Digite a temperatura em Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print("A temperatura em Fahrenheit é:", fahrenheit)

# %%
numero1 = int(input("Digite o primeiro número inteiro: "))
numero2 = int(input("Digite o segundo número inteiro: "))
numero3 = float(input("Digite um número real: "))

produto = (numero1 * 2) * (numero2 / 2)
soma = (numero1 * 3) + numero3
cubo = numero3 ** 3

print("Produto do dobro do primeiro com metade do segundo:", produto)
print("Soma do triplo do primeiro com o terceiro:", soma)
print("O terceiro número elevado ao cubo é:", cubo)

# %%
altura = float(input("Digite sua altura em metros: "))

peso_ideal = (72.7 * altura) - 58

print("Seu peso ideal seria aproximadamente:", peso_ideal, "kg")
